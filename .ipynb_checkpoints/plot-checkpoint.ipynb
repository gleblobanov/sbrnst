# %% [markdown]
# # Г. Ю. Лобанов. Построение графиков частотности и дисперсии форм слов "соборность", "социабельность", "социальность", "всеединство" в работах Г. Д. Гурвича, Н. Н. Алексеева, С. И. Гессена 1917-1943 гг.

# %% [markdown]
# Исследование выполнено при поддержке РФФИ, проект № 19-011-00927, «Концепт соборности в философии русского зарубежья: сравнительно-исторический анализ»
#
# This study is supported by the Russian Foundation for Basic Research, Project No. 19-011-00927 «The Concept of Conciliarity in the Philosophy of the Russian Emigration: a Comparative Historical Investigation».

# %% [markdown]
# ***

# %% [markdown]
# Для хранения текстов использована СУБД [PostgreSQL 12](https://www.postgresql.org/). Для парсинга источников использована библиотека оптического распознавания символов [Tesseract OCR](https://github.com/tesseract-ocr/tesseract). Скрипты обращения к БД и конструирования корпуса написаны на [Python](https://www.python.org/) с использованием библиотеки NLTK. Графики построены с помощью библиотеке [Matplotlib](https://matplotlib.org/).

# %%
import search # Модуль, реализующий обращение к базе данных. https://github.com/gleblobanov/sbrnst Автор: Г. Ю. Лобанов
import matplotlib.pyplot as plt
from nltk.text import Text

# %% [markdown]
# В корпус собраны тексты Г. Д. Гурвича, Н. Н. Алексеев и С. И. Гессен периода с 1917 по 1943 гг. Размер корпуса 1'854'035 слов.

# %%
corpus_all = search.create_corpus_all()
len(corpus_all.words())
# Out:
# utf_8_encode() argument 1 must be str, not None
# 1854035

# %% [markdown]
# ***

# %% [markdown]
# Функция `get_series` принимает аргументами начальную подстроку слова и идентификационный номер автора (1 - Г. Д. Гурвич, 2 - Н. Н. Алексеев, 3 - С. И. Гессен). Выгружает из базы данных набор текстов указанного автора и упорядоченных по годам. Для каждого года подсчитывает количество слов, которые начинаются с указанной подстроки. Возвращается последовательность элементов, хранящих год и соответствующее ему значение -- количество найденных описанным выше способом слов в этот год.

# %%
def get_series(token_part, author):
    res = {}
    for year in range(1917, 2000):
        try:
            corpus = search.create_corpus(author, year)
            text = Text(corpus.words())
            corpus.fileids()
            search_words = [w for w in text if w.startswith(token_part)]
            res[year] = len(search_words)
        except Exception:
            pass
    return res

# %% [markdown]
# Поочередно для каждого из авторов строим последовательности, представляющие частоту употребление форм каждого из рассматриваемых слов.

# %%
tokens = ["собор", "социаб", "социальн", "общежит", "всеедин"]

# Гурвич

gurvich1 = get_series(tokens[0], 1)
gurvich2 = get_series(tokens[1], 1)
gurvich3 = get_series(tokens[2], 1)
gurvich4 = get_series(tokens[3], 1)
gurvich5 = get_series(tokens[4], 1)

# Алексеев

alekseev1 = get_series(tokens[0], 2)
alekseev2 = get_series(tokens[1], 2)
alekseev3 = get_series(tokens[2], 2)
alekseev4 = get_series(tokens[3], 2)
alekseev5 = get_series(tokens[4], 2)

# Гессен

gessen1 = get_series(tokens[0], 3)
gessen2 = get_series(tokens[1], 3)
gessen3 = get_series(tokens[2], 3)
gessen4 = get_series(tokens[3], 3)
gessen5 = get_series(tokens[4], 3)
# Out:
# utf_8_encode() argument 1 must be str, not None
# utf_8_encode() argument 1 must be str, not None
# utf_8_encode() argument 1 must be str, not None
# utf_8_encode() argument 1 must be str, not None
# utf_8_encode() argument 1 must be str, not None

# %% [markdown]
# Строим графики для каждого из авторов. Каждый график содержит пять линий, изображающих изменение частоты употребления форм рассматриваемых слов от года к году.

# %%
fig, axs = plt.subplots(3, figsize = (20,20))
fig.suptitle('Графики частотности форм слов "соборность", "социабельность", "социальность", "всеединство"')

axs[0].plot(gurvich1.keys(), gurvich1.values(), label = tokens[0])
axs[0].plot(gurvich2.keys(), gurvich2.values(), label = tokens[1])
axs[0].plot(gurvich3.keys(), gurvich3.values(), label = tokens[2])
axs[0].plot(gurvich4.keys(), gurvich4.values(), label = tokens[3])
axs[0].plot(gurvich5.keys(), gurvich5.values(), label = tokens[4])
axs[0].legend()
axs[0].axis([1917, 1945, 0, 60])
axs[0].set_title('Г. Д. Гурвич')

axs[1].plot(alekseev1.keys(), alekseev1.values(), label = tokens[0])
axs[1].plot(alekseev2.keys(), alekseev2.values(), label = tokens[1])
axs[1].plot(alekseev3.keys(), alekseev3.values(), label = tokens[2])
axs[1].plot(alekseev4.keys(), alekseev4.values(), label = tokens[3])
axs[1].plot(alekseev5.keys(), alekseev5.values(), label = tokens[4])
axs[1].legend()
axs[1].axis([1917, 1945, 0, 90])
axs[1].set_title('Н. Н. Алексеев')

axs[2].plot(gessen1.keys(), gessen1.values(), label = tokens[0])
axs[2].plot(gessen2.keys(), gessen2.values(), label = tokens[1])
axs[2].plot(gessen3.keys(), gessen3.values(), label = tokens[2])
axs[2].plot(gessen4.keys(), gessen4.values(), label = tokens[3])
axs[2].plot(gessen5.keys(), gessen5.values(), label = tokens[4])
axs[2].legend()
axs[2].axis([1917, 1945, 0, 60])
axs[2].set_title('С. И. Гессен')



plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## Дисперсия форм слов "соборность", "социабельность", "социальность", "всеединство" по корпусу

# %% [markdown]
# Построим графики дисперсии (разброса) форм слов по корпусу для каждого из авторов. Разделим корпус на тексты по авторству и упорядочим по годам.

# %% [markdown]
# ## Г. Д. Гурвич

# %%
corpus = search.create_corpus_author(1)

text = Text(corpus.words())

# %% [markdown]
# Для каждого слова перечислим все его формы, встречающиеся в текстах. Далее на графике для каждой формы отметим черточкой ее расположение в корпусе. Так как тексты упорядочены по времени, то и слова тоже упорядочены по времени их появления в корпусе.

# %%
search_words = [w for w in text if w.startswith('собор')]
search_words = list(dict.fromkeys(search_words))
plt.figure(figsize=(10, 20))
text.dispersion_plot(search_words)
print(search_words)
# Out:
# ['соборпость', 'соборномь', 'соборный', 'соборная', 'соборныхъ', 'соборными', 'соборные', 'соборно', 'соборнымъ', 'соборпые', 'соборпаго', 'соборе', 'соборного', 'собориаго', 'собориую', 'собор', 'соборное', 'соборностью', 'соборному', 'соборности', 'соборность', 'соборнаго', 'соборной', 'соборноеть']

# %%
search_words = [w for w in text if w.startswith('социаб')]
search_words = list(dict.fromkeys(search_words))
plt.figure(figsize=(10, 10))
text.dispersion_plot(search_words)
print(search_words)
# Out:
# ['социабельно', 'социабильности', 'социабель', 'социабельностью', 'социабельность', 'социабельности']

# %%
search_words = [w for w in text if w.startswith('социальн')]
search_words = list(dict.fromkeys(search_words))
plt.figure(figsize=(10, 20))
text.dispersion_plot(search_words)
print(search_words)
# Out:
# ['социальнымн', 'социальна', 'социальнук', 'социальны', 'социальность', 'социально', 'социальному', 'социальный', 'социальными', 'социальности', 'социальным', 'социальном', 'социальные', 'социальная', 'социальных', 'социального', 'социальное', 'социальную', 'социальной']

# %%
search_words = [w for w in text if w.startswith('общежит')]
search_words = list(dict.fromkeys(search_words))
plt.figure(figsize=(10, 10))
text.dispersion_plot(search_words)
print(search_words)
# Out:
# ['общежительной', 'общежительная', 'общежитш', 'общежит1емъ', 'общежитйо', 'общежитЕ', 'общежит1я', 'общежития', 'общежити', 'общежитии', 'общежит']

# %%
search_words = [w for w in text if w.startswith('всеедин')]
search_words = list(dict.fromkeys(search_words))
plt.figure(figsize=(10, 10))
text.dispersion_plot(search_words)
print(search_words)
# Out:
# ['всеединого', 'всеединому', 'всеединой', 'всеединству', 'всеединстве', 'всеединством', 'всеедин', 'всеединст', 'всеединство', 'всеединства']

# %% [markdown]
# ## Н. Н. Алексеев

# %%
corpus = search.create_corpus_author(2)

text = Text(corpus.words())

# %%
search_words = [w for w in text if w.startswith('собор')]
search_words = list(dict.fromkeys(search_words))

plt.figure(figsize=(10, 10))
text.dispersion_plot(search_words)
print(search_words)
# Out:
# ['соборный', 'соборе', 'соборностью', 'соборности', 'соборная', 'соборным', 'соборной', 'соборна', 'соборное', 'собором', 'соборные', 'собор', 'собора']

# %%
search_words = [w for w in text if w.startswith('социаб')]
search_words = list(dict.fromkeys(search_words))

plt.figure(figsize=(10, 5))
text.dispersion_plot(search_words)
print(search_words)
# Out:
# []

# %%
search_words = [w for w in text if w.startswith('социальн')]
search_words = list(dict.fromkeys(search_words))

plt.figure(figsize=(10, 20))
text.dispersion_plot(search_words)
print(search_words)
# Out:
# ['социальному', 'социальные', 'социальную', 'социальными', 'социальная', 'социальным', 'социальна', 'социальных', 'социально', 'социальном', 'социальный', 'социальной', 'социальное', 'социального']

# %%
search_words = [w for w in text if w.startswith('общежит')]
search_words = list(dict.fromkeys(search_words))

plt.figure(figsize=(10, 15))
text.dispersion_plot(search_words)
print(search_words)
# Out:
# ['общежительная', 'общежительной', 'общежите', 'общежительное', 'общежити', 'общежит', 'общежитель', 'общежительности', 'общежитя', 'общежития', 'общежитиях', 'общежитий', 'общежитие', 'общежитии']

# %%
search_words = [w for w in text if w.startswith('всеедин')]
search_words = list(dict.fromkeys(search_words))

plt.figure(figsize=(10, 10))
text.dispersion_plot(search_words)
print(search_words)
# Out:
# ['всеедин', 'всеединствЪ', 'всеединства', 'всеединстве', 'всеединством', 'всеединство']

# %% [markdown]
# ## С. И. Гессен

# %%
corpus = search.create_corpus_author(3)

text = Text(corpus.words())
# Out:
# utf_8_encode() argument 1 must be str, not None

# %%
search_words = [w for w in text if w.startswith('собор')]
search_words = list(dict.fromkeys(search_words))

plt.figure(figsize=(10, 10))
text.dispersion_plot(search_words)
print(search_words)
# Out:
# ['соборность', 'соборный', 'соборно', 'собор', 'соборного', 'соборную', 'соборпо', 'соборное', 'соборен', 'соборе']

# %%
search_words = [w for w in text if w.startswith('социаб')]
search_words = list(dict.fromkeys(search_words))

plt.figure(figsize=(10, 5))
text.dispersion_plot(search_words)
print(search_words)
# Out:
# []

# %%
search_words = [w for w in text if w.startswith('социальн')]
search_words = list(dict.fromkeys(search_words))

plt.figure(figsize=(10, 20))
text.dispersion_plot(search_words)
print(search_words)
# Out:
# ['социальному', 'социальные', 'социальную', 'социальными', 'социальная', 'социальным', 'социальна', 'социальных', 'социально', 'социальном', 'социальный', 'социальной', 'социальное', 'социального']

# %%
search_words = [w for w in text if w.startswith('общежит')]
search_words = list(dict.fromkeys(search_words))

plt.figure(figsize=(10, 5))
text.dispersion_plot(search_words)
print(search_words)
# Out:
# ['общежитии', 'общежития', 'общежительный', 'общежитие']

# %%
search_words = [w for w in text if w.startswith('всеедин')]
search_words = list(dict.fromkeys(search_words))

plt.figure(figsize=(10, 5))
text.dispersion_plot(search_words)
print(search_words)
# Out:
# ['всеединствомъ', 'всеедин', 'всеединству', 'всеединая']
